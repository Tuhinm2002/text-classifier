# %%
import re
import json
import csv
import numpy as np

# %%
import sklearn
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
import string
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /home/tuhin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/tuhin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/tuhin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# ! pip install kaggle
# from google.colab import files
# files.upload()
# ! mkdir -p ~/.kaggle
# ! cp kaggle.json ~/.kaggle/

# ! chmod 600 ~/.kaggle/kaggle.json 

# # copy api command
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
#      <input type="file" id="files-f52f0504-628b-44bc-8446-a6d3d85db226" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f52f0504-628b-44bc-8446-a6d3d85db226">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# ! kaggle datasets download -d bittlingmayer/amazonreviews
# Out:
# amazonreviews.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# from zipfile import ZipFile
# file_name="amazonreviews.zip"

# with ZipFile(file_name,'r') as zip:
#   zip.extractall()
#   print("done")
# Out:
# done

# %%
# ! kaggle datasets download -d kazanova/sentiment140
# Out:
# sentiment140.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# from zipfile import ZipFile
# file_name="sentiment140.zip"

# with ZipFile(file_name,'r') as zip:
#   zip.extractall()
#   print("done")
# Out:
# done

# %%
# ! sudo apt install bzip2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# bzip2 is already the newest version (1.0.6-8.1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# ! bzip2 -d train.ft.txt.bz2
# Out:
# bzip2: Output file train.ft.txt already exists.

# %%
# ! bzip2 -d test.ft.txt.bz2
# Out:
# bzip2: Output file test.ft.txt already exists.

# %%
data1=pd.read_csv("spam.csv")

# %%
with open("Sarcasm_Headlines_Dataset_v2.json","r") as f:
    data2 = [json.loads(line) for line in f]

# %%
with open("Sarcasm_Headlines_Dataset.json","r") as f:
    data3 = [json.loads(line) for line in f]

# %%
file=open("training.1600000.processed.noemoticon.csv",encoding = 'Latin-1')
s_reader=[i for i in csv.reader(file)]

# %%
len(s_reader)
# Out:
# 1600000

# %%
s_reader[-400000:]
# Out:
# [['4',
#   '1985419426',
#   'Sun May 31 17:04:02 PDT 2009',
#   'NO_QUERY',
#   'TaylorDeCicco',
#   'danielle is the best thing since cheese in a can! '],
#  ['4',
#   '1985419430',
#   'Sun May 31 17:04:02 PDT 2009',
#   'NO_QUERY',
#   'themoderngal',
#   '@roxyreeb You need a new hobby. Wanna train for a triathlon with me? '],
#  ['4',
#   '1985419460',
#   'Sun May 31 17:04:02 PDT 2009',
#   'NO_QUERY',
#   'rachfran',
#   'loooves my friends, and as of today loves the chillness of sundays! '],
#  ['4',
#   '1985419474',
#   'Sun May 31 17:04:02 PDT 2009',
#   'NO_QUERY',
#   'giiirly',
#   'the hills  last one D:'],
#  ['4',
#   '1985419514',
#   'Sun May 31 17:04:02 PDT 2009',
#   'NO_QUERY',
#   'ilovepushplaay',
#   'teamviewer is entertaining '],
#  ['4',
#   '1985419535',
#   'Sun May 31 17:04:03 PDT 2009',
#   'NO_QUERY',
#   'folieameghan',
#   'i intensely miss my bestfriends! much love!!  [two more days]'],
#  ['4',
#   '1985419536',
#   'Sun May 31 17:04:03 PDT 2009',
#   'NO_QUERY',
#   'misfitsxgurl138',
#   "Watching the Hills season finale!!! Can't wait for the world premier of the New Moon clip!!!! "],
#  ['4',
#   '1985419568',
#   'Sun May 31 17:04:03 PDT 2009',
#   'NO_QUERY',
#   'asribour',
#   'The Hills and MTV music awards  what a way to end my weekend!'],
#  ['4',
#   '1985419672',
#   'Sun May 31 17:04:03 PDT 2009',
#   'NO_QUERY',
#   'Zweibz7',
#   '@KempEquine thanks  It was a lot of fun!'],
#  ['4',
#   '1985419724',
#   'Sun May 31 17:04:04 PDT 2009',
#   'NO_QUERY',
#   'MizzTxNy',
#   "@JerZDre nothin much doin' the same--&gt;its a Sunday I feel like I'm breaking a rule by doin' anything today besides chill "],
#  ['4',
#   '1985419725',
#   'Sun May 31 17:04:04 PDT 2009',
#   'NO_QUERY',
#   'Zweibz7',
#   '@KempEquine thanks  It was a lot of fun!'],
#  ['4',
#   '1985419727',
#   'Sun May 31 17:04:04 PDT 2009',
#   'NO_QUERY',
#   'kikiharestad',
#   'is lovin the sun '],
#  ['4',
#   '1985419753',
#   'Sun May 31 17:04:04 PDT 2009',
#   'NO_QUERY',
#   'DianeLovesJB',
#   "just one hour left to the awards  ... watchin' the red carpet right now! @ashleytisdale u look amazing "],
#  ['4',
#   '1985419759',
#   'Sun May 31 17:04:04 PDT 2009',
#   'NO_QUERY',
#   'ChristophRawrr',
#   '80.6 Fahrenheit tomorrow  Going to the beach  this has been the most amazing week its seldom every warm in Scotland'],
#  ['4',
#   '1985419793',
#   'Sun May 31 17:04:04 PDT 2009',
#   'NO_QUERY',
#   'justyesterday',
#   '@gypsymoondesign Way to go!  I am more than 100 photos behind.... I should stop twittering and get started '],
#  ['4',
#   '1985419800',
#   'Sun May 31 17:04:04 PDT 2009',
#   'NO_QUERY',
#   'danieldryzek',
#   'After 1.5 years I am bact to TRAFFIC domain conference, cool  This time in Amsterdam about ccTLDs. http://targetedtraffic.com'],
#  ['4',
#   '1985419813',
#   'Sun May 31 17:04:04 PDT 2009',
#   'NO_QUERY',
#   'lisastarlynn',
#   '@freewebaddress Thanks for the follow! '],
#  ['4',
#   '1985419896',
#   'Sun May 31 17:04:05 PDT 2009',
#   'NO_QUERY',
#   'gardenJess',
#   'Just had green tea and honey.  Was calming, and waking all at once.  '],
#  ['4',
#   '1985419916',
#   'Sun May 31 17:04:05 PDT 2009',
#   'NO_QUERY',
#   'fashionxjunkie',
#   'bought a touchscreen camera today.  now at the theater watching up 3D.'],
#  ['4',
#   '1985419936',
#   'Sun May 31 17:04:05 PDT 2009',
#   'NO_QUERY',
#   'lixyb',
#   "wow, Nadal's out of the #frenchopen... !!!?!?! GOOOO FEDS, the door's wide open!!!!! "],
#  ['4',
#   '1985419947',
#   'Sun May 31 17:04:07 PDT 2009',
#   'NO_QUERY',
#   'Amador323',
#   'no plans.. might go out for a walk on sunset blvd and enjoy some sun.. what about you? '],
#  ['4',
#   '1985419992',
#   'Sun May 31 17:04:05 PDT 2009',
#   'NO_QUERY',
#   'mobarger',
#   '@mhaithaca I am so glad you enjoyed the ribs! '],
#  ['4',
#   '1985420059',
#   'Sun May 31 17:04:06 PDT 2009',
#   'NO_QUERY',
#   'AmandaArchie',
#   "@listen2thelyrix http://twitpic.com/5i6sn - hahaha. that's beautiful  btw, i'm like commenting on all of your pictures "],
#  ['4',
#   '1985420146',
#   'Sun May 31 17:04:07 PDT 2009',
#   'NO_QUERY',
#   '_DanWest',
#   'right bed calls. Nite all '],
#  ['4',
#   '1985420176',
#   'Sun May 31 17:04:07 PDT 2009',
#   'NO_QUERY',
#   'DanuF',
#   '@vandolicious heyyy you wanna take me home tmrw '],
#  ['4',
#   '1985420260',
#   'Sun May 31 17:04:08 PDT 2009',
#   'NO_QUERY',
#   'RiellyNicole',
#   'ahh lol im so hungry and i have a MAJOR headache idk why. maybe im constipated ahaha jkjk i poop just fine ask anna '],
#  ['4',
#   '1985420298',
#   'Sun May 31 17:04:08 PDT 2009',
#   'NO_QUERY',
#   'silvi_feuer',
#   '@purplelyna none of thos movies are in my Likes list '],
#  ['4',
#   '1985420301',
#   'Sun May 31 17:04:08 PDT 2009',
#   'NO_QUERY',
#   'the_beth',
#   'modest mouse is the shit '],
#  ['4',
#   '1985420446',
#   'Sun May 31 17:04:09 PDT 2009',
#   'NO_QUERY',
#   'storybox',
#   'Watching [title of show]. '],
#  ['4',
#   '1985420469',
#   'Sun May 31 17:04:09 PDT 2009',
#   'NO_QUERY',
#   'Jenny_M12',
#   '@RobPattzNews omg girl lucky uuu..say hii to rob for us '],
#  ['4',
#   '1985420510',
#   'Sun May 31 17:04:09 PDT 2009',
#   'NO_QUERY',
#   'mlucus',
#   'Whew! What a great weekend!! '],
#  ['4',
#   '1985420534',
#   'Sun May 31 17:04:09 PDT 2009',
#   'NO_QUERY',
#   'jimmiereign',
#   '@swiffmusic @therocprince i came to Miami...right in the middle of a storm! going home tomorrow '],
#  ['4',
#   '1985420707',
#   'Sun May 31 17:04:11 PDT 2009',
#   'NO_QUERY',
#   'stemannion',
#   "@AdamHoban -IT WILL NOT RAIN ON THE 17th OF JUNE!! I am planning to sleep in Ste Brennan's back garden that night! I'll be horrendified! "],
#  ['4',
#   '1985420751',
#   'Sun May 31 17:04:11 PDT 2009',
#   'NO_QUERY',
#   'RedheadRose',
#   "@AnaCristina78 Aw thanks! That'll be nice. Look forward to your blog too!  x"],
#  ['4',
#   '1985420752',
#   'Sun May 31 17:04:11 PDT 2009',
#   'NO_QUERY',
#   'ReScUeMeGoD',
#   'Printin out some pics of Haley and I to put on my &quot;Picture wall&quot;. '],
#  ['4',
#   '1985420820',
#   'Sun May 31 17:04:12 PDT 2009',
#   'NO_QUERY',
#   'Wildolivia',
#   'Watched Star Trek &quot;AGAIN&quot; ... cant wait for my next round .... maybe tomorrow at IMAX ... '],
#  ['4',
#   '1985420880',
#   'Sun May 31 17:04:12 PDT 2009',
#   'NO_QUERY',
#   'GlasgowGooner',
#   '@Street3 Same to you. May get another heads up '],
#  ['4',
#   '1985420895',
#   'Sun May 31 17:04:12 PDT 2009',
#   'NO_QUERY',
#   'AnnaRoocha',
#   "@ddlovato - I've just buy your cd.. little too late i know but i love it .... very good music, love the guitaar in it "],
#  ['4',
#   '1985420899',
#   'Sun May 31 17:04:12 PDT 2009',
#   'NO_QUERY',
#   'tiffyhiggy',
#   "@fronztheman2009 WOOHOO! let's have pancakes! "],
#  ['4',
#   '1985420903',
#   'Sun May 31 17:04:12 PDT 2009',
#   'NO_QUERY',
#   'aleskywalker',
#   "@mariecookie thanks mariecookie! I wasn't sure about wearing it! But now I am! "],
#  ['4',
#   '1985420925',
#   'Sun May 31 17:04:12 PDT 2009',
#   'NO_QUERY',
#   'fridayluv',
#   '@larrykim thanks for the #followfriday - Kind regards to Boston City '],
#  ['4',
#   '1985421063',
#   'Sun May 31 17:04:13 PDT 2009',
#   'NO_QUERY',
#   'Pal_tm_',
#   'Anathema!! Two days and one hour.... '],
#  ['4',
#   '1985421065',
#   'Sun May 31 17:04:13 PDT 2009',
#   'NO_QUERY',
#   'farmgeek',
#   "@Danjite you're welcome to borrow mine any time you are in Masterton "],
#  ['4',
#   '1985421075',
#   'Sun May 31 17:04:13 PDT 2009',
#   'NO_QUERY',
#   'Luna_Wolf',
#   "Well, the inlaws are here, and so far so good.  The only thing that's really come up is the smell from the rats... no biggie. "],
#  ['4',
#   '1985421117',
#   'Sun May 31 17:04:14 PDT 2009',
#   'NO_QUERY',
#   'RosalieCullen',
#   '@nmyers89 Oh its something I picked up on by listening to SM your supposed to say it at the beginning of a new month lol '],
#  ['4',
#   '1985421122',
#   'Sun May 31 17:04:14 PDT 2009',
#   'NO_QUERY',
#   'TheDCD',
#   '@sp8des *waves* Hellooooo?  '],
#  ['4',
#   '1985421180',
#   'Sun May 31 17:04:14 PDT 2009',
#   'NO_QUERY',
#   'iamcaitlinmarie',
#   'bahahahahaha. she just pronounced &quot;we have wi-fi&quot; as &quot;we have wee-fee&quot; as we were walking out of panera. ohmygod she cracks me up '],
#  ['4',
#   '1985421182',
#   'Sun May 31 17:04:14 PDT 2009',
#   'NO_QUERY',
#   'la_chicca',
#   '@Dr0id hey! disaster successfully avoided  '],
#  ['4',
#   '1985421193',
#   'Sun May 31 17:04:14 PDT 2009',
#   'NO_QUERY',
#   'mjtam',
#   "@FindingAmanda  lol...funny!  No one can replace you guys.  I'm there for an Oscar Mayer Event called State of the Sandwich Conference. "],
#  ['4',
#   '1985421196',
#   'Sun May 31 17:04:14 PDT 2009',
#   'NO_QUERY',
#   'Tanny18',
#   'Is so ready to sleep, Finally got in  What an awesome day in church, Decisions were made! Whooop!'],
#  ['4',
#   '1985421262',
#   'Sun May 31 17:04:15 PDT 2009',
#   'NO_QUERY',
#   'booksandtoys',
#   'just got off the phone w/Lamar '],
#  ['4',
#   '1985421373',
#   'Sun May 31 17:04:15 PDT 2009',
#   'NO_QUERY',
#   'chris_marsh21',
#   "@vonplanta http://twitpic.com/6bxsm - You guys must be having a ball, looks like you're getting pretty buggered though  Must be HARD  ..."],
#  ['4',
#   '1985421454',
#   'Sun May 31 17:04:16 PDT 2009',
#   'NO_QUERY',
#   'SoapsDiva',
#   "@RobPattzNews We're so jealous!  "],
#  ['4',
#   '1985421495',
#   'Sun May 31 17:04:16 PDT 2009',
#   'NO_QUERY',
#   'babyxkeiks',
#   'The finale with my madre in lawww '],
#  ['4',
#   '1985421510',
#   'Sun May 31 17:04:16 PDT 2009',
#   'NO_QUERY',
#   'suubihope',
#   'tired, sore, humbled. story of my life '],
#  ['4',
#   '1985421521',
#   'Sun May 31 17:04:16 PDT 2009',
#   'NO_QUERY',
#   'chelthom',
#   'I. Hate. Sidney. Crosby. GO WINGS!! '],
#  ['4',
#   '1985421537',
#   'Sun May 31 17:04:17 PDT 2009',
#   'NO_QUERY',
#   'xxgabi',
#   '@frenchiep chineseeeeee!! '],
#  ['4',
#   '1985421552',
#   'Sun May 31 17:04:17 PDT 2009',
#   'NO_QUERY',
#   'donnam13',
#   '@megansasweetie  sometimes my age gets the better of me too! especially when it comes to cs. @jedijenn helped me see my own error.'],
#  ['4',
#   '1985421646',
#   'Sun May 31 17:04:17 PDT 2009',
#   'NO_QUERY',
#   'RozFoucault',
#   'had and excellent dinner with my favourite son and his girl '],
#  ['4',
#   '1985421663',
#   'Sun May 31 17:04:17 PDT 2009',
#   'NO_QUERY',
#   'Imkristinhogan',
#   'The Mtv Movie Awards gonna be Fun!  See u there guys '],
#  ['4',
#   '1985421672',
#   'Sun May 31 17:04:17 PDT 2009',
#   'NO_QUERY',
#   'angelinred659',
#   'Reading for the first time since vacation '],
#  ['4',
#   '1985421733',
#   'Sun May 31 17:04:18 PDT 2009',
#   'NO_QUERY',
#   'edhat1',
#   '@smont hi hun,really cool thnx, luv the idea of the poetry slam, love poetry and reading it and listening so it will be great fun,hun! '],
#  ['4',
#   '1985421743',
#   'Sun May 31 17:04:18 PDT 2009',
#   'NO_QUERY',
#   'breeziibabyax3',
#   '@hon3ydiphazel glad you noticed   ... twitter pops rock !'],
#  ['4',
#   '1985421786',
#   'Sun May 31 17:04:18 PDT 2009',
#   'NO_QUERY',
#   'Dr_Jared',
#   '@Peter_Nehem http://whatsinthebox.nl/ is #IWITB check it out...its really interesting for coders, and gamers '],
#  ['4',
#   '1985421804',
#   'Sun May 31 17:04:18 PDT 2009',
#   'NO_QUERY',
#   'kennyeatsbrains',
#   'Went swimming today  great tomorrow back to school and its a B day :|'],
#  ['4',
#   '1985421926',
#   'Sun May 31 17:04:19 PDT 2009',
#   'NO_QUERY',
#   'markdavidson',
#   "@GraftFinder In theory, that is supposed to work but in reality, not so much. I keep hitting that 'x' though. "],
#  ['4',
#   '1985421954',
#   'Sun May 31 17:04:19 PDT 2009',
#   'NO_QUERY',
#   'kiwitravwriter',
#   '@marieteather PS I have NEVER been a demure woman . nor looked for english gentlemen! '],
#  ['4',
#   '1985421958',
#   'Sun May 31 17:04:19 PDT 2009',
#   'NO_QUERY',
#   'grassmanmatt',
#   "I'm playing Valkyrie Profile on my DSi and watching Deadliest Warrior on Spike.  Win, win situation "],
#  ['4',
#   '1985421999',
#   'Sun May 31 17:04:20 PDT 2009',
#   'NO_QUERY',
#   'nessacollins',
#   'I can see the carpet '],
#  ['4',
#   '1985422011',
#   'Sun May 31 17:04:20 PDT 2009',
#   'NO_QUERY',
#   '88liizzyy',
#   'Watching the hills season finally '],
#  ['4',
#   '1985422042',
#   'Sun May 31 17:04:20 PDT 2009',
#   'NO_QUERY',
#   'Shad3s0fgr4y',
#   "I just got free marbles from work. I think it's time I get a fish tank! "],
#  ['4',
#   '1985422044',
#   'Sun May 31 17:04:20 PDT 2009',
#   'NO_QUERY',
#   'ankitkhare',
#   'living in an awesome place in San Carlos !!! Come visit '],
#  ['4',
#   '1985422095',
#   'Sun May 31 17:04:20 PDT 2009',
#   'NO_QUERY',
#   'kasiafink',
#   "Great seeing you at Dream Dress Auction @ilovefrocks. Can't wait to come shopping for frocks! Mom still talking about brown polka dots. "],
#  ['4',
#   '1985422144',
#   'Sun May 31 17:04:21 PDT 2009',
#   'NO_QUERY',
#   'lizabeth_m',
#   '@mannyfonseca woah dte is packed! uh i wish i was there. except for like dave matthews or something '],
#  ['4',
#   '1985422219',
#   'Sun May 31 17:04:21 PDT 2009',
#   'NO_QUERY',
#   'jonomallanyk',
#   "Two new Most Valuable Puppet ads - Lil' Dez http://tr.im/mZrB &amp; Car Jump http://tr.im/mZrQ - Lil' Dez is my new favourite "],
#  ['4',
#   '1985422274',
#   'Sun May 31 17:04:21 PDT 2009',
#   'NO_QUERY',
#   'Kat1819',
#   '@SongzYuuup - Heyyyyyyyyyyyy Treyyyy ..  .'],
#  ['4',
#   '1985435922',
#   'Sun May 31 17:05:54 PDT 2009',
#   'NO_QUERY',
#   'HushedAffection',
#   "Can you eat Animal crackers if you're a vegetarian? HAHAHAAAA!! That just cracks me up! "],
#  ['4',
#   '1985435941',
#   'Sun May 31 17:05:54 PDT 2009',
#   'NO_QUERY',
#   'willy_joe',
#   "It's Monday. Gonna be a great week ahead. Going to get my jeans taperred later. I just love skinnies! "],
#  ['4',
#   '1985435983',
#   'Sun May 31 17:05:54 PDT 2009',
#   'NO_QUERY',
#   'PinkerJewel',
#   '@hollybird Hi Holly!  We missed you too.  Where have you been?'],
#  ['4',
#   '1985435986',
#   'Sun May 31 17:05:54 PDT 2009',
#   'NO_QUERY',
#   'notrachel',
#   '@Megan_Burgess um, I think you can handle it.  ps, the little notebooks are great!'],
#  ['4',
#   '1985435994',
#   'Sun May 31 17:05:55 PDT 2009',
#   'NO_QUERY',
#   'LadyLeeT',
#   '@kspidel HA. Not in a professional environment though, correct? '],
#  ['4',
#   '1985436051',
#   'Sun May 31 17:05:55 PDT 2009',
#   'NO_QUERY',
#   'kristengrimes',
#   'bout to go get my new kitten!  fur family increases to four '],
#  ['4',
#   '1985436053',
#   'Sun May 31 17:05:55 PDT 2009',
#   'NO_QUERY',
#   'ColettaDerito',
#   'Watching The Hills!!! '],
#  ['4',
#   '1985436065',
#   'Sun May 31 17:05:55 PDT 2009',
#   'NO_QUERY',
#   'lynnlove70',
#   'Their doing 7 at the beacon shud b interesting 2 c it live Kelly '],
#  ['4',
#   '1985436081',
#   'Sun May 31 17:05:57 PDT 2009',
#   'NO_QUERY',
#   'sjsemmler',
#   "@umtrey You are so welcome.  One of the best Triangle nights I've had in a while. "],
#  ['4',
#   '1985436110',
#   'Sun May 31 17:05:55 PDT 2009',
#   'NO_QUERY',
#   'seth_svp',
#   '@nirty I agree, diversity of characters is a good thing. Gotta have some1 to love, some1 to hate, and some1 to not be sure about! '],
#  ['4',
#   '1985436137',
#   'Sun May 31 17:05:55 PDT 2009',
#   'NO_QUERY',
#   'BloodyRoseProd',
#   '@officialTila hey   http://mypict.me/2egc'],
#  ['4',
#   '1985436225',
#   'Sun May 31 17:05:56 PDT 2009',
#   'NO_QUERY',
#   'abesilberstein',
#   '@pennjillette AMC makes crap shows (my opinion '],
#  ['4',
#   '1985436245',
#   'Sun May 31 17:05:56 PDT 2009',
#   'NO_QUERY',
#   'AndyChajon',
#   'I just love iTunes  My bro just got back from texas!'],
#  ['4',
#   '1985436262',
#   'Sun May 31 17:05:56 PDT 2009',
#   'NO_QUERY',
#   'VickyVP',
#   '@TheOlimbs:  you working in the evening? '],
#  ['4',
#   '1985436308',
#   'Sun May 31 17:05:57 PDT 2009',
#   'NO_QUERY',
#   'coffee_snob',
#   '@moonscribe well you must be feeling very lucky  I think regional/rural vic is lovely. Hope to get there 1 day. Close but out of melb'],
#  ['4',
#   '1985436311',
#   'Sun May 31 17:05:57 PDT 2009',
#   'NO_QUERY',
#   'SneakZkiD86',
#   'Corn on the cob, fried chicken,baked mac n CheZ, canDy yamz,corn BreaD, mustard gReenz etc..... = Bomb sunday diNner!!!!  my FAm is th ...'],
#  ['4',
#   '1985436319',
#   'Sun May 31 17:05:57 PDT 2009',
#   'NO_QUERY',
#   'audiojam68',
#   '@fesworks what am I physic now?  '],
#  ['4',
#   '1985436354',
#   'Sun May 31 17:05:57 PDT 2009',
#   'NO_QUERY',
#   'ongtengco',
#   'Just woke up  going to goof around today. Less than 3 weeks before classes starts,  damn!'],
#  ['4',
#   '1985436399',
#   'Sun May 31 17:05:57 PDT 2009',
#   'NO_QUERY',
#   'iPhoneFuzzball',
#   'Playing Fuzzball reminds me of Pro-Life  http://fuzz-ball.com/twitter'],
#  ['4',
#   '1985436445',
#   'Sun May 31 17:05:58 PDT 2009',
#   'NO_QUERY',
#   'JohnPrather',
#   "@JackieHernandez hehe it's been a long time snice i've been on twitter. i've been getting twtter withdrawals since my computer broke  lol"],
#  ['4',
#   '1985436455',
#   'Sun May 31 17:05:58 PDT 2009',
#   'NO_QUERY',
#   'xoxmillyxox',
#   'less than an hour now '],
#  ['4',
#   '1985436457',
#   'Sun May 31 17:05:58 PDT 2009',
#   'NO_QUERY',
#   'kewestrawberry',
#   'so am i about to go see my long lost buddy or what!  *~smile~*'],
#  ['4',
#   '1985436499',
#   'Sun May 31 17:05:58 PDT 2009',
#   'NO_QUERY',
#   'koshilais',
#   'Hey @x17online saludos crepusculochile   (X17Live live &gt; http://ustre.am/39qb)'],
#  ['4',
#   '1985436587',
#   'Sun May 31 17:05:59 PDT 2009',
#   'NO_QUERY',
#   'ohhaimegan',
#   "Looking for band merch for a decent price?...check out my friend Taylor's stuff up for sale  http://bit.ly/pW00I"],
#  ['4',
#   '1985436598',
#   'Sun May 31 17:06:00 PDT 2009',
#   'NO_QUERY',
#   'Xyense',
#   'Finally done with season 2 of X-Men: Evolution! Watching season 3 now! Woohoo! '],
#  ['4',
#   '1985436599',
#   'Sun May 31 17:05:59 PDT 2009',
#   'NO_QUERY',
#   'ISPgypsy',
#   '@adamsandler My 9 year old and I loved u in bedtime stories. Are you going to give me a Ferrari for freeeeeeeeee? Glad to find u here! '],
#  ['4',
#   '1985436660',
#   'Sun May 31 17:05:59 PDT 2009',
#   'NO_QUERY',
#   'sagewhistler',
#   "@emeraldjaguar Heh, he's a monkey. "],
#  ['4',
#   '1985436672',
#   'Sun May 31 17:05:59 PDT 2009',
#   'NO_QUERY',
#   'BrianaBananas',
#   'Uploading a new Taylor Swift video '],
#  ['4',
#   '1985436682',
#   'Sun May 31 17:05:59 PDT 2009',
#   'NO_QUERY',
#   'ewelinka1115',
#   '@ashleytisdale http://twitpic.com/6ddox - Awesome! The best of luck to you Ashley!   '],
#  ['4',
#   '1985436702',
#   'Sun May 31 17:05:59 PDT 2009',
#   'NO_QUERY',
#   'breaniee',
#   'Ate to much '],
#  ['4',
#   '1985436721',
#   'Sun May 31 17:06:00 PDT 2009',
#   'NO_QUERY',
#   'amarie2209',
#   'bumpin to @solangeknowles &quot;god given name&quot;  dats da shit '],
#  ['4',
#   '1985436835',
#   'Sun May 31 17:06:00 PDT 2009',
#   'NO_QUERY',
#   'OrlandCaampued',
#   'at the Y enjoying an amstel then out to Corsons Inlet to fish with the boy$.  http://twitpic.com/6ddup'],
#  ['4',
#   '1985436861',
#   'Sun May 31 17:06:00 PDT 2009',
#   'NO_QUERY',
#   'princess1986',
#   "@lopskino ya it's gotten a lot busier at work I actually have 2 work  how u?"],
#  ['4',
#   '1985436920',
#   'Sun May 31 17:06:01 PDT 2009',
#   'NO_QUERY',
#   'CourtneyofDoom',
#   '@kabifff Oh man, the ducks made my day '],
#  ['4',
#   '1985436959',
#   'Sun May 31 17:06:01 PDT 2009',
#   'NO_QUERY',
#   'virtual4now',
#   '@fishyillini Thanks!  now, off to find a training plan.... and train! '],
#  ['4',
#   '1985437041',
#   'Sun May 31 17:06:02 PDT 2009',
#   'NO_QUERY',
#   'DaveLair',
#   'Hey Everyone, Please go http://bit.ly/pgrnW and vote for my blog! I got a late start due to a family weekend at the nick hotel '],
#  ['4',
#   '1985437074',
#   'Sun May 31 17:06:02 PDT 2009',
#   'NO_QUERY',
#   'Miss__Anne',
#   'It is officially the first day of winter! Yay '],
#  ['4',
#   '1985437111',
#   'Sun May 31 17:06:02 PDT 2009',
#   'NO_QUERY',
#   'cadences',
#   'is so happy  im not sure why just in a good mood'],
#  ['4',
#   '1985437185',
#   'Sun May 31 17:06:03 PDT 2009',
#   'NO_QUERY',
#   'galleysmith',
#   "@mitaliaandme I'm totally game!  "],
#  ['4',
#   '1985437213',
#   'Sun May 31 17:06:03 PDT 2009',
#   'NO_QUERY',
#   'micoproblemado',
#   "@chicgeek When their closing all their doors and they don't want you anymore it sounds funny but I'll say it anyway... girl I'll stay! "],
#  ['4',
#   '1985437232',
#   'Sun May 31 17:06:03 PDT 2009',
#   'NO_QUERY',
#   'koco1205',
#   "@taylorswift13 your dateline special was amazing! i recorded it on DVR and i'll watch it again later...you're so awesome "],
#  ['4',
#   '1985437240',
#   'Sun May 31 17:06:03 PDT 2009',
#   'NO_QUERY',
#   'vulcansmuse',
#   '@RobFarva I think it was the combination of the gun size and how long I stayed out for the first time. Fun times. '],
#  ['4',
#   '1985437313',
#   'Sun May 31 17:06:04 PDT 2009',
#   'NO_QUERY',
#   'julieannlim18',
#   "gudmrng  it's Monday again."],
#  ['4',
#   '1985437420',
#   'Sun May 31 17:06:04 PDT 2009',
#   'NO_QUERY',
#   'moneymike305',
#   '@officialRedd yeah u already know '],
#  ['4',
#   '1985437429',
#   'Sun May 31 17:06:04 PDT 2009',
#   'NO_QUERY',
#   'Nelia23',
#   '@IssacBenAvram So I am grateful for everyone that is in my life! So blessings and love to each and every one of you! ==&gt; Love you too!!! '],
#  ['4',
#   '1985437445',
#   'Sun May 31 17:06:04 PDT 2009',
#   'NO_QUERY',
#   'KatieArttt',
#   "I put so much into myself today. ahah, not really.  It's all been put into my homework!  http://tinyurl.com/kj3vlm"],
#  ['4',
#   '1985437517',
#   'Sun May 31 17:06:05 PDT 2009',
#   'NO_QUERY',
#   'gencarter',
#   "@sethsimonds I don't. "],
#  ['4',
#   '1985437523',
#   'Sun May 31 17:06:05 PDT 2009',
#   'NO_QUERY',
#   'bowlingballx',
#   '@alittlegenius Reopening of Bowling Ball '],
#  ['4',
#   '1985437542',
#   'Sun May 31 17:06:07 PDT 2009',
#   'NO_QUERY',
#   'willowtreesburn',
#   'i cant WAIT TIL WARPED TOUR!  i wanna meet CRAIGERY OWENS '],
#  ['4',
#   '1985437615',
#   'Sun May 31 17:06:06 PDT 2009',
#   'NO_QUERY',
#   'Toinky',
#   "massage was fantastic except masseuse pushed so hard he made me cough.  also... what's up with the butt slapping? otherwise, excellent. "],
#  ['4',
#   '1985437634',
#   'Sun May 31 17:06:06 PDT 2009',
#   'NO_QUERY',
#   'buonaluce',
#   "@AldoRisolvo you're welcome, I really like it. Simple yet effective. And joyful. I'd hang it in my home "],
#  ['4',
#   '1985437642',
#   'Sun May 31 17:06:06 PDT 2009',
#   'NO_QUERY',
#   'beccans',
#   "@tommcfly you're gonna appear on tv right now.. the interview at the radio on friday.. it's gonna be funny  xx"],
#  ['4',
#   '1985437647',
#   'Sun May 31 17:06:06 PDT 2009',
#   'NO_QUERY',
#   'r3shaianel',
#   "@mileycyrus LOL. I've never seen a 'cool' scar. "],
#  ['4',
#   '1985437678',
#   'Sun May 31 17:06:06 PDT 2009',
#   'NO_QUERY',
#   'f69',
#   'MU rÃ¹a lÃ\xa0 tháº¿ nÃ\xa0o nhá»\x89?   - TTVNOL.com: Iem cá»§a cÃ¡c bÃ¡c Ä\x91á»?c bÃ¡o tháº¥y nÃ³i nhiá»?u vá»? MU rÃ¹a mÃ\xa0 cháº£ hiá»\x83u gÃ¬ cáº£.  .. http://bit.ly/8kFXi'],
#  ['4',
#   '1985437708',
#   'Sun May 31 17:06:06 PDT 2009',
#   'NO_QUERY',
#   'joolzp1',
#   'Goonight tweeps and @thesselonious who will be blazin somewhere....@drizzle772 whose skatin somewhere '],
#  ['4',
#   '1985437759',
#   'Sun May 31 17:06:07 PDT 2009',
#   'NO_QUERY',
#   'mirandafurtado',
#   'Correction: Drinking Moet and about to start watching Zeitgeist after a well- recommended suggestion from a friend '],
#  ['4',
#   '1985437787',
#   'Sun May 31 17:06:07 PDT 2009',
#   'NO_QUERY',
#   'peelingpaper',
#   "@modVoxPop I hope our kitty wasn't too much trouble for you .  Me thinks I owe you some vegan brownies "],
#  ['4',
#   '1985437903',
#   'Sun May 31 17:06:08 PDT 2009',
#   'NO_QUERY',
#   'kelserdoo882962',
#   'Waiting for the mtv movie awards to come on so i can see new moon trailer and zac efron '],
#  ['4',
#   '1985437913',
#   'Sun May 31 17:06:08 PDT 2009',
#   'NO_QUERY',
#   'nelzon',
#   "@ThatKevinSmith it's a honor to able to follow you here  greetings from Hungary."],
#  ['4',
#   '1985437996',
#   'Sun May 31 17:06:08 PDT 2009',
#   'NO_QUERY',
#   'clarephile',
#   "it's a dimsum kind of day. "],
#  ['4',
#   '1985438021',
#   'Sun May 31 17:06:08 PDT 2009',
#   'NO_QUERY',
#   'ImTaylorParks',
#   'watching the season finale of the hills  make sure you votevotevote for @mileycyrus for the mtv awards '],
#  ['4',
#   '1985438031',
#   'Sun May 31 17:06:08 PDT 2009',
#   'NO_QUERY',
#   'charmaineraynbo',
#   "I'm drinking juice "],
#  ['4',
#   '1985438097',
#   'Sun May 31 17:06:09 PDT 2009',
#   'NO_QUERY',
#   'Undezcovered',
#   'Okay... so fuck it, I just followed a lot of people! '],
#  ['4',
#   '1985438102',
#   'Sun May 31 17:06:09 PDT 2009',
#   'NO_QUERY',
#   'inkophile',
#   '@Phthalo Well, DH might came around someday. If not, we have two generations here that appreciate fine pens especially super fine nibs. '],
#  ['4',
#   '1985438120',
#   'Sun May 31 17:06:09 PDT 2009',
#   'NO_QUERY',
#   'daniellemb',
#   'Aw my pet duck just came to visit me! '],
#  ['4',
#   '1985438301',
#   'Sun May 31 17:06:10 PDT 2009',
#   'NO_QUERY',
#   'TerinAleah',
#   'watching the Hills finale then the MTV Movie Awards!! '],
#  ['4',
#   '1985438344',
#   'Sun May 31 17:06:11 PDT 2009',
#   'NO_QUERY',
#   'PassionMD',
#   '@xanaxgirl nothing wrong with a weekend of chillaxing.  you doing well?'],
#  ['4',
#   '1985438462',
#   'Sun May 31 17:06:11 PDT 2009',
#   'NO_QUERY',
#   'rerkaizen',
#   "@RadioBarz and i'm honored that you're #1000 .. and looking forward to exchanging blips "],
#  ['4',
#   '1985438486',
#   'Sun May 31 17:06:11 PDT 2009',
#   'NO_QUERY',
#   'minauderie',
#   "@CandyMaize that's good logic "],
#  ['4',
#   '1985438502',
#   'Sun May 31 17:06:12 PDT 2009',
#   'NO_QUERY',
#   'Kelsoats',
#   'A beautiful day! Enjoying the breeze and the birds '],
#  ['4',
#   '1985438565',
#   'Sun May 31 17:06:14 PDT 2009',
#   'NO_QUERY',
#   'AlisaHofer',
#   '@pamfidler Sorry to hear you have allergies. So frustrating this time of year. Glad you had nice weather though. '],
#  ['4',
#   '1985438630',
#   'Sun May 31 17:06:12 PDT 2009',
#   'NO_QUERY',
#   'MissLadyDanger',
#   '@katahay i cant make aw it  wish i could..hopefully its on a Weekend next time soo it wont be a problem for me  love you Kata xoxo Carina'],
#  ['4',
#   '1985438753',
#   'Sun May 31 17:06:13 PDT 2009',
#   'NO_QUERY',
#   'raeraesunshine',
#   '@charlenewithit immat yogurtland  you dont even have leftovers?'],
#  ['4',
#   '1985438838',
#   'Sun May 31 17:06:14 PDT 2009',
#   'NO_QUERY',
#   'kidkrunk',
#   'U just need one big break!!! and with all da talent u got I sure one is on the way!!! '],
#  ['4',
#   '1985438981',
#   'Sun May 31 17:06:15 PDT 2009',
#   'NO_QUERY',
#   'nosferatu1208',
#   "@emilytasticz0rz I was at Schlotzsky's  yesterday "],
#  ['4',
#   '1985439035',
#   'Sun May 31 17:06:15 PDT 2009',
#   'NO_QUERY',
#   'ag_chillaxn',
#   "another weekend almost over, it's going to be a tough Mon &amp; Tues this week. I see LOTS of iced coffees in my future. they keep me happy "],
#  ['4',
#   '1985439045',
#   'Sun May 31 17:06:15 PDT 2009',
#   'NO_QUERY',
#   'leahfalkowski',
#   'Photography writers/bloggers - DM or @ reply me please  #blog #photography #writing #togs #photo'],
#  ['4',
#   '1985439095',
#   'Sun May 31 17:06:16 PDT 2009',
#   'NO_QUERY',
#   'jordanshootsppl',
#   'jared has arrived! '],
#  ['4',
#   '1985439120',
#   'Sun May 31 17:06:16 PDT 2009',
#   'NO_QUERY',
#   'bmar',
#   "I liked 'Up' because the little boy looked like XY's baby picture...  &lt;3"],
#  ['4',
#   '1985439127',
#   'Sun May 31 17:06:16 PDT 2009',
#   'NO_QUERY',
#   'nenny',
#   'Early Birthday lunch, shopping, and homemade egg rolls for dinner...i love my mommy!! '],
#  ['4',
#   '1985439163',
#   'Sun May 31 17:06:16 PDT 2009',
#   'NO_QUERY',
#   'christina_voss',
#   'trying to write essays, feeling sick and STILL tired from the weekend but HAPPY '],
#  ['4',
#   '1985439281',
#   'Sun May 31 17:06:17 PDT 2009',
#   'NO_QUERY',
#   'carrieyourown',
#   'Just got my first ever debit card. Ohhhh the power '],
#  ['4',
#   '1985439289',
#   'Sun May 31 17:06:17 PDT 2009',
#   'NO_QUERY',
#   'SummerBrealFly',
#   "I Think I'm Fallin' In Love "],
#  ['4',
#   '1985439366',
#   'Sun May 31 17:06:18 PDT 2009',
#   'NO_QUERY',
#   'alohagurl06',
#   'DP leaders BBQ  golden gardens is packeddd'],
#  ['4',
#   '1985439404',
#   'Sun May 31 17:06:18 PDT 2009',
#   'NO_QUERY',
#   'piratescribe',
#   '@hypersensitive wahoo! I did that a week or two ago '],
#  ['4',
#   '1985439411',
#   'Sun May 31 17:06:18 PDT 2009',
#   'NO_QUERY',
#   'superwoman4002',
#   'AWESOME AWESOME AWESOME giveaway at http://bit.ly/qjb2A  '],
#  ['4',
#   '1985439433',
#   'Sun May 31 17:06:18 PDT 2009',
#   'NO_QUERY',
#   'SamEbs',
#   "I want a puppy! AND, I've picked out the one that I want! "],
#  ['4',
#   '1985439717',
#   'Sun May 31 17:06:20 PDT 2009',
#   'NO_QUERY',
#   'CatherineC22',
#   'watching youtube videos with amy! '],
#  ['4',
#   '1985439837',
#   'Sun May 31 17:06:21 PDT 2009',
#   'NO_QUERY',
#   'misscox',
#   "Haha, I meant 'fishing' not 'dishing'. No gissip around the fish! "],
#  ['4',
#   '1985439862',
#   'Sun May 31 17:06:21 PDT 2009',
#   'NO_QUERY',
#   'toniakande',
#   'following 100 people! wowsers. thanks for following me '],
#  ['4',
#   '1985439867',
#   'Sun May 31 17:06:21 PDT 2009',
#   'NO_QUERY',
#   'JPHackworth',
#   "@joia be careful, I hear that's bat country "],
#  ['4',
#   '1985439881',
#   'Sun May 31 17:06:21 PDT 2009',
#   'NO_QUERY',
#   'keagless',
#   'watchinnn some tv &amp; showerin \\ relaxin till i fall aleep '],
#  ['4',
#   '1985439904',
#   'Sun May 31 17:06:21 PDT 2009',
#   'NO_QUERY',
#   'abacab1973',
#   "@Gailporter Lol - Well, if it's any comfort, you've now got more followers than Suzi Perry  Glad you finally got some kip yesterday!"],
#  ['4',
#   '1985439926',
#   'Sun May 31 17:06:21 PDT 2009',
#   'NO_QUERY',
#   'BWSGameFan',
#   "MTV Movie Awards on tonight...haven't watched MTV (or BET) in 8+ months...and I'd like to keep that going. "],
#  ['4',
#   '1985453376',
#   'Sun May 31 17:07:55 PDT 2009',
#   'NO_QUERY',
#   'andrsdtz',
#   'watched lovely beckys blogtv show and now watch http://www.blogtv.com/people/michaeltang awesome show. check him out '],
#  ['4',
#   '1985453394',
#   'Sun May 31 17:07:55 PDT 2009',
#   'NO_QUERY',
#   'BethHeinbeck',
#   "Excited to watch the VMA's and see Kings of Leon perform!!!!  I miss them "],
#  ['4',
#   '1985453406',
#   'Sun May 31 17:07:55 PDT 2009',
#   'NO_QUERY',
#   'xtscreamhx',
#   '@nicolejeanx3 request mi on facebook '],
#  ['4',
#   '1985453434',
#   'Sun May 31 17:07:56 PDT 2009',
#   'NO_QUERY',
#   'emmaftw',
#   'My friend is having a bonfire tonight. Im pretty excited '],
#  ['4',
#   '1985453440',
#   'Sun May 31 17:07:56 PDT 2009',
#   'NO_QUERY',
#   'k0zm0zs0ul',
#   '@GayleTrent  Your very welcome Gayle! I hope you get it sorted. '],
#  ['4',
#   '1985453527',
#   'Sun May 31 17:07:56 PDT 2009',
#   'NO_QUERY',
#   'P_Dub88',
#   "It's been a long day. Goin out to dinner in 15 mins "],
#  ['4',
#   '1985453549',
#   'Sun May 31 17:07:56 PDT 2009',
#   'NO_QUERY',
#   'jobroxlove',
#   '@andrearamboyong haha yeah, i have gum wrappers all over my stuff. and church can make you sleepy '],
#  ['4',
#   '1985453656',
#   'Sun May 31 17:07:57 PDT 2009',
#   'NO_QUERY',
#   'kelvinringold',
#   "@LeesaB Assume a virtue and it's yours   Ego is not (necessarily) cocky. Ego is confident assurance. Yes, I can. Yes, I *am*. You are ;)"],
#  ['4',
#   '1985453669',
#   'Sun May 31 17:07:57 PDT 2009',
#   'NO_QUERY',
#   'MarkSheppard',
#   "@johnfbraun ha ha...  Now I get it.  It's a testosterone thing.  "],
#  ['4',
#   '1985453686',
#   'Sun May 31 17:07:57 PDT 2009',
#   'NO_QUERY',
#   'crazie617',
#   '@marcyville let me kno how it is after u see it I wanna see Drag me 2 Hell when I get a day off '],
#  ['4',
#   '1985453735',
#   'Sun May 31 17:07:58 PDT 2009',
#   'NO_QUERY',
#   'britta_mas',
#   '@Elle_reid  any ideas .  23days&lt;3'],
#  ['4',
#   '1985453894',
#   'Sun May 31 17:07:59 PDT 2009',
#   'NO_QUERY',
#   '8chkay8ch',
#   'Would you like to join me?   http://twitpic.com/6de14'],
#  ['4',
#   '1985453921',
#   'Sun May 31 17:07:59 PDT 2009',
#   'NO_QUERY',
#   'giiab',
#   '@jtimberlake I love you! i wanna see you @ MTV Movie Awards!!!!!! '],
#  ['4',
#   '1985453935',
#   'Sun May 31 17:08:00 PDT 2009',
#   'NO_QUERY',
#   'jamiewatson',
#   "@HeyLookItsKathy I don't know if granny would actually *do* it, but she'd tell him to his face that she would *like* to do it. "],
#  ['4',
#   '1985453949',
#   'Sun May 31 17:08:00 PDT 2009',
#   'NO_QUERY',
#   'kITAkATTmONROE',
#   '@pgrossi lol well thxs hun but its actually supposed to fit big but I LOVE IT! &amp; i guess thats all that matters  thxs for ur input?!?!'],
#  ['4',
#   '1985453972',
#   'Sun May 31 17:08:00 PDT 2009',
#   'NO_QUERY',
#   'cmuah',
#   'day has been lovely so far, as it will continue! Time for some cardio, reading for class tomorrow thheen round 2 of seeing my hunny! '],
#  ['4',
#   '1985454061',
#   'Sun May 31 17:08:00 PDT 2009',
#   'NO_QUERY',
#   'ash8184',
#   "i bought myself a piece of waterford crystal today.  it's in the shape of a heart and makes me feel oh-so-girly. i like it. "],
#  ['4',
#   '1985454072',
#   'Sun May 31 17:08:01 PDT 2009',
#   'NO_QUERY',
#   'chocoseduction',
#   '@onelove2686 {singin} I GOT NO TIME 4 FAKE ONES....u kno da rest '],
#  ['4',
#   '1985454078',
#   'Sun May 31 17:08:01 PDT 2009',
#   'NO_QUERY',
#   'S_Wash',
#   '@nukemdomis Hey, are you mocking me!   lol!'],
#  ['4',
#   '1985454136',
#   'Sun May 31 17:08:01 PDT 2009',
#   'NO_QUERY',
#   'mommysnacks',
#   "@MomTalkRadio well, I don't think I've ever heard Wifey!!! But, Soulja boy was hip enough  Sounds like it was another great Disney Mixer!!"],
#  ['4',
#   '1985454164',
#   'Sun May 31 17:08:01 PDT 2009',
#   'NO_QUERY',
#   'archfanatic13',
#   "I love that Wendy's commercial for the...COFFEE TOFFEE, TWISTED FROSTYY. It's great! "],
#  ['4',
#   '1985454171',
#   'Sun May 31 17:08:01 PDT 2009',
#   'NO_QUERY',
#   'mauraaaa',
#   '@BaeaTom congrats on graduating tom tom! '],
#  ['4',
#   '1985454183',
#   'Sun May 31 17:08:01 PDT 2009',
#   'NO_QUERY',
#   'Dan0608',
#   "@anitacochran don't think I told you Happy Birthday.. but hope you had a great one  "],
#  ['4',
#   '1985454203',
#   'Sun May 31 17:08:01 PDT 2009',
#   'NO_QUERY',
#   'fictionalpants',
#   'Chris Forbes is on ABC Classic FM this morning '],
#  ['4',
#   '1985454328',
#   'Sun May 31 17:08:02 PDT 2009',
#   'NO_QUERY',
#   'CandyMaize',
#   '@minauderie so it is not JUST me that thinks this way then '],
#  ['4',
#   '1985454414',
#   'Sun May 31 17:08:03 PDT 2009',
#   'NO_QUERY',
#   'caseycoleman',
#   "@cheeky_geeky: Note--never attend State of Union address if you're tired of applauding. "],
#  ['4',
#   '1985454419',
#   'Sun May 31 17:08:03 PDT 2009',
#   'NO_QUERY',
#   'drivelbaby',
#   '@Shaunosaurus Aww that sounds excellent, I hope it all works out mister! I do like it when things go right '],
#  ['4',
#   '1985454427',
#   'Sun May 31 17:08:03 PDT 2009',
#   'NO_QUERY',
#   'joshcorbo',
#   "@CoreyLay If you can admit to admiring Miley, there's no shame in feeling the same about Ashley. "],
#  ['4',
#   '1985454431',
#   'Sun May 31 17:08:03 PDT 2009',
#   'NO_QUERY',
#   'schachin',
#   "How much of what you are thinking isn't true? - Wayne Dyer  (ex negative thoughts about yourself)"],
#  ['4',
#   '1985454458',
#   'Sun May 31 17:08:03 PDT 2009',
#   'NO_QUERY',
#   'mklopez',
#   '@chaisecandie try driving over the bay, that always inspires me in one way or the other '],
#  ['4',
#   '1985454467',
#   'Sun May 31 17:08:03 PDT 2009',
#   'NO_QUERY',
#   'jrenee9556',
#   'sunday night baseball. '],
#  ['4',
#   '1985454468',
#   'Sun May 31 17:08:03 PDT 2009',
#   'NO_QUERY',
#   'mnjorgensen',
#   'Off for  a walk up Wild Dog Creek road ... then back through the bush and home for a coffee. Tweet you in an hour or two '],
#  ['4',
#   '1985454529',
#   'Sun May 31 17:08:04 PDT 2009',
#   'NO_QUERY',
#   'Sabrinaaa_',
#   'Ew, tomorrow is school. But summer is just around the corner. '],
#  ['4',
#   '1985454540',
#   'Sun May 31 17:08:04 PDT 2009',
#   'NO_QUERY',
#   'MrzSteph',
#   'Making a steak and shrimp feast for my neighbor. He is the dessert, I mean, he is bringing dessert '],
#  ['4',
#   '1985454552',
#   'Sun May 31 17:08:04 PDT 2009',
#   'NO_QUERY',
#   'katherinedec',
#   'YAYY OMMGGG the NEW MOOON TRAILERR TONIGHHTTT '],
#  ['4',
#   '1985454652',
#   'Sun May 31 17:08:04 PDT 2009',
#   'NO_QUERY',
#   'Lukewygodny',
#   'Just recorded a new song called, &quot;Heart to Hold.&quot; Should be up soon. '],
#  ['4',
#   '1985454697',
#   'Sun May 31 17:08:05 PDT 2009',
#   'NO_QUERY',
#   'payunirbabae',
#   '@crossapol I wish!I have to enter all the addresses and then note nearest to farthest and thats how we work them.Takes longer but works. '],
#  ['4',
#   '1985454745',
#   'Sun May 31 17:08:05 PDT 2009',
#   'NO_QUERY',
#   'Seth_Clearwater',
#   '@Only_Leah  Leah you are the bestest big sister ever! I LOVE YOU!'],
#  ['4',
#   '1985454878',
#   'Sun May 31 17:08:06 PDT 2009',
#   'NO_QUERY',
#   'SHOOTNFISH',
#   '@c_harris at the point you need more room it might be fun to stick the kids in their own small tent too or do a guys and gals thing. '],
#  ['4',
#   '1985454890',
#   'Sun May 31 17:08:06 PDT 2009',
#   'NO_QUERY',
#   'urvaksh',
#   "@pfreet I'm not following you (too depressing), just twitter stalking ya  @peoplebrowsr makes it ez. EM me the idea?"],
#  ['4',
#   '1985454897',
#   'Sun May 31 17:08:06 PDT 2009',
#   'NO_QUERY',
#   'DjShonen',
#   "NEW CAT   Her name, according to my mum, is Gracie. But that's gay, so I'm gonna call her Aminal. I like that... http://tinyurl.com/ldgzrl"],
#  ['4',
#   '1985455002',
#   'Sun May 31 17:08:07 PDT 2009',
#   'NO_QUERY',
#   'daveizzle',
#   'http://twitpic.com/6de1m - Hmmm... Do I want this person following me? '],
#  ['4',
#   '1985455023',
#   'Sun May 31 17:08:07 PDT 2009',
#   'NO_QUERY',
#   'NikoleCamarae',
#   "Dave and busters  i'm excited ha its going to be a longgg night."],
#  ['4',
#   '1985455083',
#   'Sun May 31 17:08:07 PDT 2009',
#   'NO_QUERY',
#   'zydrate_user_25',
#   'Had such a fucking blast last night!!! Hope to do it again soon. '],
#  ['4',
#   '1985455096',
#   'Sun May 31 17:08:08 PDT 2009',
#   'NO_QUERY',
#   'Shukria',
#   'just saw &quot;UP&quot; wih my step son and hubby, so cute! great story '],
#  ['4',
#   '1985455138',
#   'Sun May 31 17:08:08 PDT 2009',
#   'NO_QUERY',
#   'rbflygal',
#   "@pittsburghmark  / @JSpikEThinG lol i know! Thought I'd be a smart ass though "],
#  ['4',
#   '1985455351',
#   'Sun May 31 17:08:09 PDT 2009',
#   'NO_QUERY',
#   'MoniKaG',
#   '@AINow Does he still has those bright yellow shoes he wore on tour?they were so cool! '],
#  ['4',
#   '1985455370',
#   'Sun May 31 17:08:09 PDT 2009',
#   'NO_QUERY',
#   'Nikkimariexx23',
#   'watching Dora with my litte sister  movie awards@ 9'],
#  ['4',
#   '1985455401',
#   'Sun May 31 17:08:09 PDT 2009',
#   'NO_QUERY',
#   'esmeg',
#   '@That_Girl_Jenn too funny. To each her own I guess '],
#  ['4',
#   '1985455445',
#   'Sun May 31 17:08:10 PDT 2009',
#   'NO_QUERY',
#   'ohboyitsfatima',
#   'I love Nevel longbottom '],
#  ['4',
#   '1985455477',
#   'Sun May 31 17:08:10 PDT 2009',
#   'NO_QUERY',
#   'graceeechen',
#   'nightmkt with my brother &amp; sister last night - get the spicy lamb skewers  also watched Ip Man - GREEEAAAT MOVIE!!!!!'],
#  ['4',
#   '1985455514',
#   'Sun May 31 17:08:10 PDT 2009',
#   'NO_QUERY',
#   'ms_naz',
#   'will upload today photos of the Chill-Out Night &amp; at the Souk Cafe...  http://plurk.com/p/xhjsy'],
#  ['4',
#   '1985455636',
#   'Sun May 31 17:08:11 PDT 2009',
#   'NO_QUERY',
#   'rtpt',
#   '@keeponrunning #musicalmess.. I understand, got a 250 GB external hard drive almost full of music..I am sure I could purge...music OCD? '],
#  ['4',
#   '1985455648',
#   'Sun May 31 17:08:11 PDT 2009',
#   'NO_QUERY',
#   'Listersmate',
#   '@officialmila You should visit my coffee shop &amp; tea room Mila.  www.stringbeancoffeeshop.com'],
#  ['4',
#   '1985455667',
#   'Sun May 31 17:08:11 PDT 2009',
#   'NO_QUERY',
#   'alyb_',
#   "@ajchevalier oh ok. That's good. I wish you luck with all that "],
#  ['4',
#   '1985455694',
#   'Sun May 31 17:08:11 PDT 2009',
#   'NO_QUERY',
#   'alleycat727',
#   'Getting ready for crazy week of twittering @medinagazette, someone please follow it so we look legit '],
#  ['4',
#   '1985455708',
#   'Sun May 31 17:08:12 PDT 2009',
#   'NO_QUERY',
#   'mdwillbefamous',
#   '@TheRealLuis one i wrote and post in YouTube '],
#  ['4',
#   '1985455745',
#   'Sun May 31 17:08:12 PDT 2009',
#   'NO_QUERY',
#   'livvysays',
#   'say hi to clarisse for me  lmao!'],
#  ['4',
#   '1985455838',
#   'Sun May 31 17:08:13 PDT 2009',
#   'NO_QUERY',
#   'brianwelburn',
#   "@juliaallison  To stop her , turn round &amp; look at the spot just above her nose, don't say a word just gaze gently &amp; she will stop ! "],
#  ['4',
#   '1985455914',
#   'Sun May 31 17:08:13 PDT 2009',
#   'NO_QUERY',
#   'NykoleAKAKole',
#   '@jmi11ion stfu w/ these &quot;followstats&quot; no one cares!!!! lol &quot;tis light-weight embarrassing son.. lol jp buddy '],
#  ['4',
#   '1985455974',
#   'Sun May 31 17:08:13 PDT 2009',
#   'NO_QUERY',
#   'misskris293',
#   'amazinggg. i loveddd the taylor swift special. it made my day! now if only the jobros would show up at the MTV movie awards... '],
#  ['4',
#   '1985455988',
#   'Sun May 31 17:08:14 PDT 2009',
#   'NO_QUERY',
#   'hortovanyi',
#   '@shaunau mate, I was on @smiffytech yesterday about perl '],
#  ['4',
#   '1985455997',
#   'Sun May 31 17:08:14 PDT 2009',
#   'NO_QUERY',
#   'veronicajones',
#   'Currently riding in the back seat of my car lol.. I decided to be nice and let the two tall guys drive and ride shotgun '],
#  ['4',
#   '1985456034',
#   'Sun May 31 17:08:14 PDT 2009',
#   'NO_QUERY',
#   'dntcareoverit',
#   'On da bridge goin back home '],
#  ['4',
#   '1985456050',
#   'Sun May 31 17:08:14 PDT 2009',
#   'NO_QUERY',
#   'daniellemariepa',
#   'take a giant step out of your mind '],
#  ['4',
#   '1985456072',
#   'Sun May 31 17:08:14 PDT 2009',
#   'NO_QUERY',
#   'maryannemorgan',
#   '@bryanscottphoto how did it go? I have always wanted to shoot on one of his sets '],
#  ['4',
#   '1985456181',
#   'Sun May 31 17:08:15 PDT 2009',
#   'NO_QUERY',
#   'TonyLovesRaevyn',
#   'Homeee greattt weeekend  ahhhh Hills tonight cant wait too juicedddd'],
#  ['4',
#   '1985456295',
#   'Sun May 31 17:08:16 PDT 2009',
#   'NO_QUERY',
#   'addikted2ballin',
#   'second place is first loser.. but not when the second place shirts look better than first places '],
#  ['4',
#   '1985456300',
#   'Sun May 31 17:08:16 PDT 2009',
#   'NO_QUERY',
#   'golden_angel_28',
#   "I'm watching my son play in his kiddie pool outside and he is such a ham!  "],
#  ['4',
#   '1985456322',
#   'Sun May 31 17:08:16 PDT 2009',
#   'NO_QUERY',
#   'BoltClock',
#   "@hellodeibu Hope so too  Except this subject still touches on &lt;font&gt; despite promising CSS lectures... it doesn't even look at JS at all."],
#  ['4',
#   '1985456324',
#   'Sun May 31 17:08:16 PDT 2009',
#   'NO_QUERY',
#   'thesamsantos',
#   "@thepatbrown Glad you're home okay mate! "],
#  ['4',
#   '1985456343',
#   'Sun May 31 17:08:16 PDT 2009',
#   'NO_QUERY',
#   'melmer',
#   "Loving this live feed of the red carpet!! I'm not sure how much more patiently i can wait for my loves!! 1 down...many to go "],
#  ['4',
#   '1985456360',
#   'Sun May 31 17:08:16 PDT 2009',
#   'NO_QUERY',
#   'gategenocide',
#   "is laughing like crazy listening to the OST of the Musical Monty Python's Spamalot!  http://plurk.com/p/xhjtj"],
#  ['4',
#   '1985456361',
#   'Sun May 31 17:08:16 PDT 2009',
#   'NO_QUERY',
#   'myohmy2boys',
#   '@woodbetony â\x80¦cont) open up    to 460 little cute pics that u can use in anything that u type '],
#  ['4',
#   '1985456389',
#   'Sun May 31 17:08:17 PDT 2009',
#   'NO_QUERY',
#   'BAM727',
#   'taylor swift i herd that she was on csi somebody plz tell me if that was true '],
#  ['4',
#   '1985456397',
#   'Sun May 31 17:08:17 PDT 2009',
#   'NO_QUERY',
#   '_oOHOo_',
#   '@naoueshima Im in Love with this one  http://bit.ly/WsTU2'],
#  ['4',
#   '1985456411',
#   'Sun May 31 17:08:17 PDT 2009',
#   'NO_QUERY',
#   'rockyemo',
#   "hmm i think i'll gonna see angels &amp; demons on friday "],
#  ['4',
#   '1985456419',
#   'Sun May 31 17:08:17 PDT 2009',
#   'NO_QUERY',
#   'Ellebella618',
#   'Mass  peace  then firefly'],
#  ['4',
#   '1985456457',
#   'Sun May 31 17:08:17 PDT 2009',
#   'NO_QUERY',
#   'lisastarlynn',
#   '@turquoisefish Thanks!  â\x99« http://blip.fm/~7efxs'],
#  ['4',
#   '1985456475',
#   'Sun May 31 17:08:17 PDT 2009',
#   'NO_QUERY',
#   'icandysensation',
#   '@AngelinaHayes Hey I just made the same thing. '],
#  ['4',
#   '1985456497',
#   'Sun May 31 17:08:17 PDT 2009',
#   'NO_QUERY',
#   'reallygus',
#   'hey twitters '],
#  ['4',
#   '1985456501',
#   'Sun May 31 17:08:17 PDT 2009',
#   'NO_QUERY',
#   'karakaejames',
#   '@cnormies I thought it was a good look for us too '],
#  ['4',
#   '1985456524',
#   'Sun May 31 17:08:18 PDT 2009',
#   'NO_QUERY',
#   'ANGELJACKIE44',
#   '@adriandayton I am glad to have you back '],
#  ['4',
#   '1985456550',
#   'Sun May 31 17:08:18 PDT 2009',
#   'NO_QUERY',
#   'Adelyte',
#   'hahaha Twitter is a good way to get information! '],
#  ['4',
#   '1985456613',
#   'Sun May 31 17:08:18 PDT 2009',
#   'NO_QUERY',
#   'cristawebster',
#   "@bayou You know you can't wait for the New Moon trailer. "],
#  ['4',
#   '1985456648',
#   'Sun May 31 17:08:19 PDT 2009',
#   'NO_QUERY',
#   'cat6270',
#   '@taylorswift13 Hey Taylor  I just watched the special, you are so incredibly talented; everything looks amazing! I wish you the best!'],
#  ['4',
#   '1985456668',
#   'Sun May 31 17:08:20 PDT 2009',
#   'NO_QUERY',
#   'musicislife722',
#   "Jose's baseball game  http://myloc.me/2eiA"],
#  ['4',
#   '1985456733',
#   'Sun May 31 17:08:19 PDT 2009',
#   'NO_QUERY',
#   'cuteecat',
#   'good morning ! '],
#  ['4',
#   '1985456858',
#   'Sun May 31 17:08:20 PDT 2009',
#   'NO_QUERY',
#   'Silverxo',
#   'cant wait for the MTV Movie Awards! i hope @mileycyrus wins in her categories.. '],
#  ['4',
#   '1985456889',
#   'Sun May 31 17:08:20 PDT 2009',
#   'NO_QUERY',
#   'missrogue',
#   'Logging out to go enjoy a real live musical performance. I may even do my hair! '],
#  ['4',
#   '1985456901',
#   'Sun May 31 17:08:20 PDT 2009',
#   'NO_QUERY',
#   'AshleyLaur',
#   "@jeweljk Just an FYI- anytime you wanna post more video blogs of you signing new songs, we're up for it!! "],
#  ['4',
#   '1985456975',
#   'Sun May 31 17:08:21 PDT 2009',
#   'NO_QUERY',
#   'VitoAngel',
#   '@Wateronfire25 poo-doe is my forever angel  give her big kisses and pee on her leg for me '],
#  ['4',
#   '1985457038',
#   'Sun May 31 17:08:21 PDT 2009',
#   'NO_QUERY',
#   'dg4G',
#   '@bcrab oh yeah '],
#  ['4',
#   '1985457057',
#   'Sun May 31 17:08:21 PDT 2009',
#   'NO_QUERY',
#   'stemannion',
#   "@PDGenius For F**k Sake. I didn't know ye were on twitter for so long. Should of been following ye ages ago! "],
#  ['4',
#   '1985457083',
#   'Sun May 31 17:08:21 PDT 2009',
#   'NO_QUERY',
#   'Mernahuana',
#   "updating weed wiki chilling with Grape Fruit and OG Kush that's Organically Grown Kush not Original Gangster "],
#  ['4',
#   '1985457097',
#   'Sun May 31 17:08:22 PDT 2009',
#   'NO_QUERY',
#   'madjean',
#   "@NikiJ2011 Haven't made 'em yet. Think I'll do that now, before I sign on AOL. "],
#  ['4',
#   '1985457275',
#   'Sun May 31 17:08:23 PDT 2009',
#   'NO_QUERY',
#   'Jeevy_Da_God',
#   '@MissMoneyMesha hello deary '],
#  ['4',
#   '1985457306',
#   'Sun May 31 17:08:23 PDT 2009',
#   'NO_QUERY',
#   'LiamW00t',
#   'I was looking over some Costa Rica pics, wow, i just remembered how BEAUTIFUL it is. '],
#  ['4',
#   '1985470073',
#   'Sun May 31 17:09:54 PDT 2009',
#   'NO_QUERY',
#   'Miss_Bellatrix',
#   'Going for a walk with @jallin '],
#  ['4',
#   '1985470123',
#   'Sun May 31 17:09:55 PDT 2009',
#   'NO_QUERY',
#   'vavroom',
#   '@tashmahal Woohooo! Congrats on the two of you. How does it feel to finally not be living in sin? '],
#  ['4',
#   '1985470233',
#   'Sun May 31 17:09:55 PDT 2009',
#   'NO_QUERY',
#   'AleahVlahakis',
#   'CSI is intense! '],
#  ['4',
#   '1985470277',
#   'Sun May 31 17:09:56 PDT 2009',
#   'NO_QUERY',
#   'PaperCakes',
#   "@paperflowershop cleaning is a great distraction isn't it? hope you feel better soon  xo"],
#  ['4',
#   '1985470306',
#   'Sun May 31 17:09:56 PDT 2009',
#   'NO_QUERY',
#   'firstmate42',
#   'Yay = finally = beautiful afternoon on the water with sails a blowin in the wind '],
#  ['4',
#   '1985470362',
#   'Sun May 31 17:09:56 PDT 2009',
#   'NO_QUERY',
#   'Shama',
#   "@TammyBurnell woo-hoo! that sounds fantastic! I can't wait to see it. "],
#  ['4',
#   '1985470378',
#   'Sun May 31 17:09:56 PDT 2009',
#   'NO_QUERY',
#   'FFaruq',
#   'Done watching Che Pt2. Great stuff! http://twitpic.com/6de6u  Love how Fidel is so teeny in that poster. '],
#  ['4',
#   '1985470518',
#   'Sun May 31 17:09:57 PDT 2009',
#   'NO_QUERY',
#   'trawryo',
#   '@frankyponce your just mad because i got a better grade than you on last chapters test . '],
#  ['4',
#   '1985470559',
#   'Sun May 31 17:09:57 PDT 2009',
#   'NO_QUERY',
#   'crystalte',
#   "Drizzling Monday morning...  It's June payroll already? 6th month of the year?! Whew... Let's go team  Lord, Your grace is enough "],
#  ['4',
#   '1985470578',
#   'Sun May 31 17:09:58 PDT 2009',
#   'NO_QUERY',
#   'jacobbrwr',
#   '@karlee_jo Yay! Haha.  I have to go eat dinner. Talk to you later'],
#  ['4',
#   '1985470605',
#   'Sun May 31 17:09:58 PDT 2009',
#   'NO_QUERY',
#   'pinktalon',
#   'new picture  but why is my old one showing??'],
#  ['4',
#   '1985470830',
#   'Sun May 31 17:10:00 PDT 2009',
#   'NO_QUERY',
#   'TashiMashi',
#   "@LazyLizzy350 LMAO .... Pediphile????? And you forgot your keys , damn! Let me drink what you've been drinkin "],
#  ['4',
#   '1985470934',
#   'Sun May 31 17:10:00 PDT 2009',
#   'NO_QUERY',
#   'javilovespizza',
#   '@the_nikster  Love you!! &lt;3333'],
#  ['4',
#   '1985470946',
#   'Sun May 31 17:10:00 PDT 2009',
#   'NO_QUERY',
#   'colebaby706',
#   'you know i got them pretty blue eyes and them thick thighs! '],
#  ['4',
#   '1985470956',
# ...
#  ['4',
#   '1985576676',
#   'Sun May 31 17:22:15 PDT 2009',
#   'NO_QUERY',
#   'AnalSexSecrets',
#   "@KinkyUKCouple I'm thinking of making a hypnosis program for anal orgasms...that kinda sounds like fun, huh? "],
#  ['4',
#   '1985576697',
#   'Sun May 31 17:22:15 PDT 2009',
#   'NO_QUERY',
#   'Lndp4',
#   "@twistedmonk yes! nudity is the answer. i'll spread the good word for a glimpse of that "],
#  ['4',
#   '1985576705',
#   'Sun May 31 17:22:15 PDT 2009',
#   'NO_QUERY',
#   'mizzconceit3d',
#   'im BACK TWITTERS  '],
#  ['4',
#   '1985576788',
#   'Sun May 31 17:22:18 PDT 2009',
#   'NO_QUERY',
#   'ShakeNBakePony',
#   "Damn, I'm just good today. In a great mood and getting work done! "],
#  ['4',
#   '1985576794',
#   'Sun May 31 17:22:16 PDT 2009',
#   'NO_QUERY',
#   'leannedao',
#   'I love my grandparents.  They always make everything soo much better.  '],
#  ['4',
#   '1985576815',
#   'Sun May 31 17:22:16 PDT 2009',
#   'NO_QUERY',
#   'ThomasHensel',
#   '@Cory_Froomkin Nice pics - now... change the world, k? '],
#  ['4',
#   '1985576845',
#   'Sun May 31 17:22:16 PDT 2009',
#   'NO_QUERY',
#   'Aidsmouth',
#   '@mothmilk I noticed '],
#  ['4',
#   '1985576897',
#   'Sun May 31 17:22:17 PDT 2009',
#   'NO_QUERY',
#   'ellenpatrice',
#   'is watching transformers because it AWESOME! '],
#  ['4',
#   '1985576915',
#   'Sun May 31 17:22:17 PDT 2009',
#   'NO_QUERY',
#   'thewearytravelr',
#   'truly a day of rest ... '],
#  ['4',
#   '1985576922',
#   'Sun May 31 17:22:17 PDT 2009',
#   'NO_QUERY',
#   'Dazzled1091',
#   'MTV MOVIE AWARDS 2009! 9PM. [be there]   {new moon!!!}'],
#  ['4',
#   '1985576967',
#   'Sun May 31 17:22:17 PDT 2009',
#   'NO_QUERY',
#   'Hetty4Christ',
#   '@jawar U always make me smile sir! Blessings my brilliant minded friend!! I may have less brain from surgeries-enough 2 know kind souls '],
#  ['4',
#   '1985577050',
#   'Sun May 31 17:22:18 PDT 2009',
#   'NO_QUERY',
#   'shanedawson',
#   '@davedays hey its been a long day. dont hate! '],
#  ['4',
#   '1985577113',
#   'Sun May 31 17:22:18 PDT 2009',
#   'NO_QUERY',
#   'elvina24',
#   'surprised by how many people &quot;like&quot; indoor bike riding. '],
#  ['4',
#   '1985577145',
#   'Sun May 31 17:22:18 PDT 2009',
#   'NO_QUERY',
#   'Ahavajora',
#   'Mid-June, Sat or Sun, at our house: Russian-themed dinner, a prime op for me to break out my favorite Rusky recipes, natch. '],
#  ['4',
#   '1985577194',
#   'Sun May 31 17:22:19 PDT 2009',
#   'NO_QUERY',
#   'Rbulman2',
#   "is glad he's on Twitter. Now he know's that his mom is in the car w/ her sweetie with the top down. He just had to know that. "],
#  ['4',
#   '1985577213',
#   'Sun May 31 17:22:19 PDT 2009',
#   'NO_QUERY',
#   'Yarllen',
#   'votando no 2009 MTV Movie Awards.   '],
#  ['4',
#   '1985577236',
#   'Sun May 31 17:22:19 PDT 2009',
#   'NO_QUERY',
#   'Listersmate',
#   "@luvyaa You can get coffee @ my family's coffee shop, we have a tea room too.  www.stringbeancoffeeshop.com"],
#  ['4',
#   '1985577392',
#   'Sun May 31 17:22:20 PDT 2009',
#   'NO_QUERY',
#   'erikurdiales',
#   "@allstationsdown today has been a good day..so i'll check you guys out "],
#  ['4',
#   '1985577398',
#   'Sun May 31 17:22:20 PDT 2009',
#   'NO_QUERY',
#   'yuaremysunshine',
#   "we're home "],
#  ['4',
#   '1985577577',
#   'Sun May 31 17:22:21 PDT 2009',
#   'NO_QUERY',
#   'jewjawsh',
#   'Back back in cali cali. With ping pong balls!  and papa murphyssss'],
#  ['4',
#   '1985577614',
#   'Sun May 31 17:22:22 PDT 2009',
#   'NO_QUERY',
#   'porshie',
#   "Is crushin' hard!!!!!!!!!!!!!!!! "],
#  ['4',
#   '1985577626',
#   'Sun May 31 17:22:22 PDT 2009',
#   'NO_QUERY',
#   'skylineproject',
#   "@thebrandbuilder i second that! (now, it's nationwide  )"],
#  ['4',
#   '1985577635',
#   'Sun May 31 17:22:22 PDT 2009',
#   'NO_QUERY',
#   '5malLfRY',
#   'so glad 2 knw that my ppl miss me so much bt im @ home looking @ the orangy sky thinking about rain..hmmm i guess i just wanna gt wet up '],
#  ['4',
#   '1985577651',
#   'Sun May 31 17:22:22 PDT 2009',
#   'NO_QUERY',
#   'kc2atl',
#   "@Jaiduh when's the next vid session?  It was pretty cool &amp; interesting "],
#  ['4',
#   '1985577706',
#   'Sun May 31 17:22:22 PDT 2009',
#   'NO_QUERY',
#   'em14o8',
#   'says morning  http://plurk.com/p/xhlo4'],
#  ['4',
#   '1985577782',
#   'Sun May 31 17:22:23 PDT 2009',
#   'NO_QUERY',
#   'DrPedobear',
#   'Finished cleaning  woo, fixing shitttt on the computer.'],
#  ['4',
#   '1985577891',
#   'Sun May 31 17:22:24 PDT 2009',
#   'NO_QUERY',
#   'joeyawesome',
#   "http://twitpic.com/6dfdq - Fun cutout we made everyone pose with at my sister's bridal shower, luau style "],
#  ['4',
#   '1985577902',
#   'Sun May 31 17:22:24 PDT 2009',
#   'NO_QUERY',
#   'asiancrunk',
#   'Twitted dance! '],
#  ['4',
#   '1985578104',
#   'Sun May 31 17:22:25 PDT 2009',
#   'NO_QUERY',
#   'kaylalynch16',
#   'watching the hills finale/mtv awards, should be good! '],
#  ['4',
#   '1985578138',
#   'Sun May 31 17:22:25 PDT 2009',
#   'NO_QUERY',
#   'EgyptoKnuckles',
#   "@Sassygirl4444 Hells yes.  Trying to work on using more of my vacay, but we'll see what's coming up soon "],
#  ['4',
#   '1985578238',
#   'Sun May 31 17:22:26 PDT 2009',
#   'NO_QUERY',
#   'alwayzlovely',
#   '@alwayzbelive  &amp; @alwayzlovely &lt;&lt; &quot;watchin God.. is all we can do&quot; '],
#  ['4',
#   '1985578315',
#   'Sun May 31 17:22:26 PDT 2009',
#   'NO_QUERY',
#   'ambahhxx',
#   'mm today was goood  finallly almost happy. summer so soon.'],
#  ['4',
#   '1985591519',
#   'Sun May 31 17:24:02 PDT 2009',
#   'NO_QUERY',
#   'HarryLyme',
#   'Norm mcdonald -- always funny -- also smart and fiercely competitive (based on password play '],
#  ['4',
#   '1985591521',
#   'Sun May 31 17:24:02 PDT 2009',
#   'NO_QUERY',
#   'CamoMark',
#   'Played ALOT of Xbox, now time to study for this HUGE Algebra Quiz! '],
#  ['4',
#   '1985591548',
#   'Sun May 31 17:24:02 PDT 2009',
#   'NO_QUERY',
#   'lordlaw',
#   'cant wait to go camping with some great friends in cornwall at beachbreak in 14 days '],
#  ['4',
#   '1985591551',
#   'Sun May 31 17:24:02 PDT 2009',
#   'NO_QUERY',
#   'w00dRabbit',
#   '@Dr_Jared it is indeed pretty impressive. extremely well done. had me watching up to the end '],
#  ['4',
#   '1985591566',
#   'Sun May 31 17:24:03 PDT 2009',
#   'NO_QUERY',
#   'Jimmysmacks',
#   '@melleboo1  IM GROWN BABY'],
#  ['4',
#   '1985591568',
#   'Sun May 31 17:24:03 PDT 2009',
#   'NO_QUERY',
#   'djJennyBlaze',
#   "Home girl just called me, says she's coming back to ny soon- like next week typa soon!!! Thanks for all the help tweeties! "],
#  ['4',
#   '1985591574',
#   'Sun May 31 17:24:03 PDT 2009',
#   'NO_QUERY',
#   'bostonbibliophl',
#   '@GirlsSentAway LOL '],
#  ['4',
#   '1985591691',
#   'Sun May 31 17:24:03 PDT 2009',
#   'NO_QUERY',
#   'itsartdammit',
#   'Everyday 3.5 mil pics are uploaded to Flickr. 500 of them are ranked best each day. Yesterday mine was one of them.  http://bit.ly/OdAA4 '],
#  ['4',
#   '1985591740',
#   'Sun May 31 17:24:04 PDT 2009',
#   'NO_QUERY',
#   'heatherbxo',
#   'MTV movie awards soon  eminem+andy samberg= AH-MAZING!'],
#  ['4',
#   '1985591742',
#   'Sun May 31 17:24:04 PDT 2009',
#   'NO_QUERY',
#   'intertruth',
#   '@jennygirl7 ur pink purple s a real scream - so true without any dream of cream.   Living love could u put back on the waves of warmth '],
#  ['4',
#   '1985591770',
#   'Sun May 31 17:24:04 PDT 2009',
#   'NO_QUERY',
#   'kickthehobbit',
#   'Srsly, need to pick up It Only Hurts When I Pee next. Maybe tomorrow. '],
#  ['4',
#   '1985591804',
#   'Sun May 31 17:24:04 PDT 2009',
#   'NO_QUERY',
#   'nwangelle',
#   'Just got home from an awesome refuge service and is about to pig out on raviolis.  haha.'],
#  ['4',
#   '1985591886',
#   'Sun May 31 17:24:05 PDT 2009',
#   'NO_QUERY',
#   'notrage',
#   '@jeffgerstmann take a pic of the Die Hard skyscrapper!!!, if your near it '],
#  ['4',
#   '1985591892',
#   'Sun May 31 17:24:05 PDT 2009',
#   'NO_QUERY',
#   'AngNewell77',
#   'http://twitpic.com/6dfin - @DanielFielding A bad representation but a great day! '],
#  ['4',
#   '1985591967',
#   'Sun May 31 17:24:05 PDT 2009',
#   'NO_QUERY',
#   'InLoveWithJonas',
#   'Yay for Taylor Swift being on Trending Topics. She deserves it '],
#  ['4',
#   '1985591988',
#   'Sun May 31 17:24:05 PDT 2009',
#   'NO_QUERY',
#   'DjShonen',
#   'Has a new cat '],
#  ['4',
#   '1985592002',
#   'Sun May 31 17:24:05 PDT 2009',
#   'NO_QUERY',
#   'victoriaalee',
#   '@ 4:13 now '],
#  ['4',
#   '1985592064',
#   'Sun May 31 17:24:06 PDT 2009',
#   'NO_QUERY',
#   'Shatohin',
#   '@mekal Ñ? Ð¢Ð²Ð¸Ñ\x82Ñ\x82ÐµÑ\x80Ð¾Ð¼ Ñ\x82Ð¾Ð¶Ðµ Ñ?Ð¾Ð²ÐµÑ\x80Ñ\x88ÐµÐ½Ð½Ð¾ Ð·Ð°Ð±Ñ\x80Ð¾Ñ?Ð¸Ð» Ñ?Ð²Ð¾Ð¹ Ð±Ð»Ð¾Ð³, ÐºÐ¾Ñ\x82Ð¾Ñ\x80Ñ\x8bÐ¹ Ñ\x82Ñ\x80Ð¸ Ð³Ð¾Ð´Ð° Ð²ÐµÐ». Ð¥Ð¾Ñ?Ñ\x82Ð¸Ð½Ð³ Ð´Ð°Ð¶Ðµ Ð¾Ñ\x82ÐºÐ»Ñ\x8eÑ\x87Ð¸Ð»Ð¸ Ñ\x83Ð¶Ðµ  Ð\x92Ð¾Ñ\x82 Ð²ÐµÐ´Ñ\x8c new media, Ñ\x87Ñ\x82Ð¾Ð± Ð¸Ñ\x85.'],
#  ['4',
#   '1985592068',
#   'Sun May 31 17:24:06 PDT 2009',
#   'NO_QUERY',
#   'chaosprincess87',
#   'Hey @x17online pls ask kellan and ash why they came together   (X17Live live &gt; http://ustre.am/39qb)'],
#  ['4',
#   '1985592137',
#   'Sun May 31 17:24:06 PDT 2009',
#   'NO_QUERY',
#   'Shakeibra',
#   'Took a nap... And Lil 1 just came home  missed her! Now time to do hair... Ugh... Maybe n the next hr... Still sleepy...'],
#  ['4',
#   '1985592171',
#   'Sun May 31 17:24:06 PDT 2009',
#   'NO_QUERY',
#   'smit1153',
#   'wed wingsss '],
#  ['4',
#   '1985592281',
#   'Sun May 31 17:24:07 PDT 2009',
#   'NO_QUERY',
#   'thenotoriouskid',
#   "@Em105 I'm all good baby...  Just letting the past go "],
#  ['4',
#   '1985592354',
#   'Sun May 31 17:24:08 PDT 2009',
#   'NO_QUERY',
#   'jamielynnbeals',
#   '@marklee3d Happy Anniversary to you &amp; @stephanietlee! I hope you have a wonderful time together in Europe! '],
#  ['4',
#   '1985592395',
#   'Sun May 31 17:24:08 PDT 2009',
#   'NO_QUERY',
#   'anbe73yo',
#   'Trying naked juice protein zone! Ill let you know how it is '],
#  ['4',
#   '1985592426',
#   'Sun May 31 17:24:08 PDT 2009',
#   'NO_QUERY',
#   'selkiesong',
#   'Last tweet courtesy of @bbcscotland '],
#  ['4',
#   '1985592450',
#   'Sun May 31 17:24:08 PDT 2009',
#   'NO_QUERY',
#   'RHE27',
#   "@TRAV51WILL that's wussup! "],
#  ['4',
#   '1985592468',
#   'Sun May 31 17:24:09 PDT 2009',
#   'NO_QUERY',
#   'FordLawnmower',
#   '@Pentenscribes I kinda like the name Gurly. It has a nice ring to it '],
#  ['4',
#   '1985592477',
#   'Sun May 31 17:24:09 PDT 2009',
#   'NO_QUERY',
#   'heathergardner',
#   'back from seeing http://disney.go.com/disneypictures/up/main.html - great movie - I give it five thumbs up '],
#  ['4',
#   '1985592501',
#   'Sun May 31 17:24:09 PDT 2009',
#   'NO_QUERY',
#   'Gabrieol',
#   "don't worry , be happy. Boa noite "],
#  ['4',
#   '1985592523',
#   'Sun May 31 17:24:09 PDT 2009',
#   'NO_QUERY',
#   'ineffable3',
#   "@meghunt http://twitpic.com/6czns - Nice! Can't wait to see the finished product - totally dig ur work "],
#  ['4',
#   '1985592539',
#   'Sun May 31 17:24:09 PDT 2009',
#   'NO_QUERY',
#   'Ashley188',
#   'Got 3.5 on my essay for CAHSEE '],
#  ['4',
#   '1985592550',
#   'Sun May 31 17:24:09 PDT 2009',
#   'NO_QUERY',
#   'Nanahra',
#   'Making my wrestling Debut on july 3rd, same day as my birthday and SGC: ScrewAttack Gaming Convention.... What a day... '],
#  ['4',
#   '1985592563',
#   'Sun May 31 17:24:09 PDT 2009',
#   'NO_QUERY',
#   'KussKuss1',
#   'i never knew neon orange was my colour '],
#  ['4',
#   '1985592573',
#   'Sun May 31 17:24:09 PDT 2009',
#   'NO_QUERY',
#   'gaks',
#   "@johnlegend John, I think it's awesome that you're an inspiration figure for education. Keep up the good work in both music and activism! "],
#  ['4',
#   '1985592587',
#   'Sun May 31 17:24:10 PDT 2009',
#   'NO_QUERY',
#   'jtl2411',
#   '@laylakayleigh very nice picture '],
#  ['4',
#   '1985592717',
#   'Sun May 31 17:24:11 PDT 2009',
#   'NO_QUERY',
#   'petermello',
#   "@saraparker If U go, check out Southwold. Great little seaside town. Stop by the Lord Nelson for a pint of Adnam's. "],
#  ['4',
#   '1985592725',
#   'Sun May 31 17:24:11 PDT 2009',
#   'NO_QUERY',
#   'jeanie0313',
#   "If you like American Idol... turn on BBC and check out &quot;Any Dream Will Do&quot; -- it's on right now.  "],
#  ['4',
#   '1985592746',
#   'Sun May 31 17:24:11 PDT 2009',
#   'NO_QUERY',
#   'brianablair',
#   "so stoked it's a harry potter marathon on abc family. my oh my the goblet of fire is on now. "],
#  ['4',
#   '1985592774',
#   'Sun May 31 17:24:11 PDT 2009',
#   'NO_QUERY',
#   'carriecuriel',
#   '@ralphp matt was getting frustrated lastnight cause he was trying to turn off twitter on my phone with no luck '],
#  ['4',
#   '1985592793',
#   'Sun May 31 17:24:11 PDT 2009',
#   'NO_QUERY',
#   'Maddatom',
#   'Wants a meat pie... but eating yogurt instead '],
#  ['4',
#   '1985592799',
#   'Sun May 31 17:24:11 PDT 2009',
#   'NO_QUERY',
#   'MusicLover7196',
#   "I'm drinking chocolate milk. "],
#  ['4',
#   '1985592820',
#   'Sun May 31 17:24:11 PDT 2009',
#   'NO_QUERY',
#   'Liv_17',
#   'Im singing my heart away '],
#  ['4',
#   '1985592840',
#   'Sun May 31 17:24:11 PDT 2009',
#   'NO_QUERY',
#   'mariahkw',
#   '@dciavola Thanks!  Feeling a bit better.  I really appreciate the ride in the morning.  See you at 7:20ish '],
#  ['4',
#   '1985592888',
#   'Sun May 31 17:24:12 PDT 2009',
#   'NO_QUERY',
#   'JKlover',
#   '@DWEENALUVSNKOTB  It was great! I loved seeing my daughter laugh &amp; learn &amp; having a great time! Very exhausting though  How r u ?'],
#  ['4',
#   '1985592952',
#   'Sun May 31 17:24:12 PDT 2009',
#   'NO_QUERY',
#   'heymaritza',
#   'Going to see jessie '],
#  ['4',
#   '1985593027',
#   'Sun May 31 17:24:13 PDT 2009',
#   'NO_QUERY',
#   'ByronBrewer',
#   'Still sorting through gifts, cards and all kinds of fun stuff.  '],
#  ['4',
#   '1985593032',
#   'Sun May 31 17:24:13 PDT 2009',
#   'NO_QUERY',
#   'aniixi',
#   'i love little big planet  suck at making levels though :/'],
#  ['4',
#   '1985593048',
#   'Sun May 31 17:24:13 PDT 2009',
#   'NO_QUERY',
#   'anjoe7',
#   "come on people, update. i'm bored   entertain me "],
#  ['4',
#   '1985593153',
#   'Sun May 31 17:24:14 PDT 2009',
#   'NO_QUERY',
#   'tpietruszynski',
#   "@greekpeace that's such a cute pic. "],
#  ['4',
#   '1985593285',
#   'Sun May 31 17:24:15 PDT 2009',
#   'NO_QUERY',
#   'simoncurtis',
#   'about to head out to see UP with @missandrealewis and mamahutch!   Really excited for this one folks'],
#  ['4',
#   '1985593334',
#   'Sun May 31 17:24:15 PDT 2009',
#   'NO_QUERY',
#   'bi0xid',
#   'Dinner with @lorelleonwp and @davemoyer  Gbye! '],
#  ['4',
#   '1985593412',
#   'Sun May 31 17:24:15 PDT 2009',
#   'NO_QUERY',
#   'jsgreyhoundgirl',
#   '@jswo cool, thanks. I will! '],
#  ['4',
#   '1985593548',
#   'Sun May 31 17:24:16 PDT 2009',
#   'NO_QUERY',
#   'AlexShalman',
#   '@bodhibuggy something tells me you and I are going to be bffaeae. '],
#  ['4',
#   '1985593608',
#   'Sun May 31 17:24:17 PDT 2009',
#   'NO_QUERY',
#   'inkedveggie',
#   '@fuzone thank you darling! That means a lot.  xoxo'],
#  ['4',
#   '1985593675',
#   'Sun May 31 17:24:17 PDT 2009',
#   'NO_QUERY',
#   'BrooklynNomad',
#   '@TravelBoldly Hey thanks for the kind words. Glad someone likes my dry humor. '],
#  ['4',
#   '1985593708',
#   'Sun May 31 17:24:18 PDT 2009',
#   'NO_QUERY',
#   'cagol',
#   '@tommcfly the name of the channel is REDETV !. '],
#  ['4',
#   '1985593771',
#   'Sun May 31 17:24:18 PDT 2009',
#   'NO_QUERY',
#   'm1ndgam3z',
#   '@snazzzy714  I know...I liked that account...but now to start off FRESH...and with NO followers LMFAO'],
#  ['4',
#   '1985593821',
#   'Sun May 31 17:24:18 PDT 2009',
#   'NO_QUERY',
#   'twilighting2',
#   '@taylorswift13 Could you please send me a message! You are amazing! '],
#  ['4',
#   '1985593881',
#   'Sun May 31 17:24:19 PDT 2009',
#   'NO_QUERY',
#   'AdiBwonderwoman',
#   "@AutumnJoi I sent you a DM...it's lookin' real good for the tv pilot "],
#  ['4',
#   '1985593907',
#   'Sun May 31 17:24:19 PDT 2009',
#   'NO_QUERY',
#   'cjaxon',
#   '@majamom a Chunk of love at the very least   He is a sweetheart, and he has the yummiest chub rolls EVER! Thank you '],
#  ['4',
#   '1985593965',
#   'Sun May 31 17:24:19 PDT 2009',
#   'NO_QUERY',
#   'zibbet',
#   '@thecraftykitten We actually only just launched in February 2009!!  Love your books!  '],
#  ['4',
#   '1985593968',
#   'Sun May 31 17:24:19 PDT 2009',
#   'NO_QUERY',
#   'schneiderk',
#   "@katzmandu true, though it could've been a good revenue-raising move for the airline &amp; would b entertaining for other passengers to watch "],
#  ['4',
#   '1985593971',
#   'Sun May 31 17:24:21 PDT 2009',
#   'NO_QUERY',
#   'shannonpaul',
#   '@cfomarshall Not a chance. '],
#  ['4',
#   '1985593988',
#   'Sun May 31 17:24:19 PDT 2009',
#   'NO_QUERY',
#   'Unkindangel',
#   'I hve an interview tomorrow at victoria secret '],
#  ...]

# %%
data4_neg=[a[0] for a in s_reader[:400000]]

# %%
data4_pos=[a[0] for a in s_reader[1200000:]]

# %%
data4=[]
for i in data4_neg:
  data4.append(i)
for j in data4_pos:
  data4.append(j)

# %%
len(data4)
# Out:
# 800000

# %%
data4_neg_=[a[5] for a in s_reader[:400000]]

# %%
data4_pos_=[a[5] for a in s_reader[1200000:]]

# %%
data4_=[]
for i in data4_neg_:
  data4_.append(i)
for j in data4_pos_:
  data4_.append(j)

# %%
len(data4_)==len(data4)
# Out:
# True

# %%
file=open("test.ft.txt",encoding="utf8")
reader=file.readlines()

# %%
data6=[j for a in reader for j in a.split(":")[0][9] if j.isnumeric()]

# %%
data6_=[a[10:] for a in reader]

# %%
len(data6),len(data6_)
# Out:
# (400000, 400000)

# %%
file1=open("train.ft.txt",encoding="utf8")
reader1=file1.readlines()

# %%
data7=[]
data7_=[]

# %%
for a in reader1:
    if a.split(":")[0][9].isnumeric():
        data7.append(a.split(":")[0][9])

# %%
for j in reader1:
    data7_.append(j[10:])

# %%
data3_label=[i["is_sarcastic"] for i in data3]
data3_=[k["headline"] for k in data3]

# %%
data2_label=[j["is_sarcastic"] for j in data2]
data2_=[k["headline"] for k in data2]

# %%
data1_=[]
for i in data1.iloc[:,0]:
    data1_.append(i)

# %%
data1_label=[]
for i in data1.iloc[:,1]:
    data1_label.append(i)

# %%
print("In data1",type(data1_label[1])),print("In data2",type(data2_label[1])),print("In data3",type(data3_label[1])),print("In data4",type(data4[1])),print("In data6",type(data6[1])),print("In data7",type(data7[1]))
# Out:
# In data1 <class 'int'>
# In data2 <class 'int'>
# In data3 <class 'int'>
# In data4 <class 'str'>
# In data6 <class 'str'>
# In data7 <class 'str'>
# (None, None, None, None, None, None)

# %%
len(data1_),len(data1_label)
# Out:
# (5728, 5728)

# %%
data4_label=[int(i) for i in data4]

# %%
len(data4)==len(data4_label)
# Out:
# True

# %%
data6_label=[int(i) for i in data6]

# %%
len(data6)==len(data6_label)
# Out:
# True

# %%
data7_label=[int(i) for i in data7]

# %%
len(data7)==len(data7_label)
# Out:
# True

# %%
data2_label_=[]
for i in data2_label:
    if i==0:
        data2_label_.append(int(str(i).replace("0","2")))
    else:
        data2_label_.append(int(str(i).replace("1","3")))

# %%
data3_label_=[]

for j in data3_label:
    if j==0:
        data3_label_.append(int(str(j).replace("0","2")))
    else:
        data3_label_.append(int(str(j).replace("1","3")))

# %%
data4_label_=[]
for k in data4_label:
    if k==0:
        data4_label_.append(int(str(k).replace("0","5")))
    elif k==4:
        data4_label_.append(4)

# %%
len(data4_label),len(data4_label_)
# Out:
# (800000, 800000)

# %%
data6_label_=[]
for a in data6_label:
    if a==1:
        data6_label_.append(int(str(a).replace("1","6")))
    elif a==2:
        data6_label_.append(int(str(a).replace("2","7")))

# %%
data7_label_=[]
for h in data7_label:
    if h==1:
        data7_label_.append(int(str(h).replace("1","6")))
    elif h==2:
        data7_label_.append(int(str(h).replace("2","7")))

# %%
reader3=pd.read_csv("train.tsv",sep='\t')

# %%
reader3
# Out:
#         PhraseId  SentenceId  \
# 0              1           1
# 1              2           1
# 2              3           1
# 3              4           1
# 4              5           1
# ...          ...         ...
# 156055    156056        8544
# 156056    156057        8544
# 156057    156058        8544
# 156058    156059        8544
# 156059    156060        8544
#
#                                                    Phrase  Sentiment
# 0       A series of escapades demonstrating the adage ...          1
# 1       A series of escapades demonstrating the adage ...          2
# 2                                                A series          2
# 3                                                       A          2
# 4                                                  series          2
# ...                                                   ...        ...
# 156055                                          Hearst 's          2
# 156056                          forced avuncular chortles          1
# 156057                                 avuncular chortles          3
# 156058                                          avuncular          2
# 156059                                           chortles          2
#
# [156060 rows x 4 columns]

# %%
data5=[]
data5_=[]

# %%
len(reader3)
# Out:
# 156060

# %%
for k in range(len(reader3)):
    if reader3.Sentiment[k]==2:
        data5_.append(reader3.Phrase[k])

# %%
for j in range(len(reader3)):
    if reader3.Sentiment[j]==2:
        data5.append(reader3.Sentiment[j])

# %%
len(data5_)==len(data5)
# Out:
# True

# %%
data5_label=[int(str(i).replace("2","8")) for i in data5]

# %%
len(data5_label)==len(data5)
# Out:
# True

# %%
type(data5_label[1])
# Out:
# int

# %%
data=[]
label=[]

# %%
len(data),len(label)
# Out:
# (0, 0)

# %%
data4_label[150000]
# Out:
# 0

# %%
len(data7_),len(data7_label_)
# Out:
# (3600000, 3600000)

# %%
for j in data1_label:
    label.append(j)

# %%
for j in data2_label_:
    label.append(j)

# %%
for j in data3_label_:
    label.append(j)

# %%
for j in data4_label_:
    label.append(j)

# %%
for j in data5_label:
    label.append(j)

# %%
for j in data6_label_:
    label.append(j)

# %%
for j in data7_label_:
    label.append(j)

# %%
len(data),len(data4_)
# Out:
# (0, 800000)

# %%
len(label)==len(data)
# Out:
# False

# %%
type(data6_[1])
# Out:
# str

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
type(data1_[1])
# Out:
# str

# %%
cv=CountVectorizer()

# %%
for a in data1_:
    data.append(a)
for j in data2_:
    data.append(j)
for i in data3_:
    data.append(i)
for o in data4_:
    data.append(o)
for k in data6_:
    data.append(k)
for n in data7_:
    data.append(n)
for m in data5_:
    data.append(m)

# %%
len(data)==len(label)
# Out:
# True

# %%
data_=cv.fit_transform(data)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data_,np.array(label),test_size=0.2,random_state=1)

# %%
data_
# Out:
# <4940638x1369101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 230556129 stored elements in Compressed Sparse Row format>

# %%
x_train
# Out:
# <3952510x1369101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 184458323 stored elements in Compressed Sparse Row format>

# %%
import pickle
# model_freeze=pickle.dump(classifier,open("Model_classifier_spam.pkl","wb"))
# vec=pickle.dump(cv,open("Count_vector.pkl","wb"))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
dte=DecisionTreeClassifier()
knn=KNeighborsClassifier()
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
